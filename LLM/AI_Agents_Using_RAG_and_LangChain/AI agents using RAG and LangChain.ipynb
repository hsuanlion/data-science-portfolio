# %% [markdown]
# # TSLA Earnings Analysis Using RAG and LangChain

# %% [markdown]
# ## Project Overview — Tesla Earnings Analysis Agent (RAG + LangChain)
#
# This notebook implements a lightweight **financial research agent** for analyzing **Tesla (TSLA) quarterly filings** using **Retrieval-Augmented Generation (RAG)**.
#
# **What it does**
# - Loads Tesla (TSLA) earnings PDFs, splits them into semantic chunks, embeds them, and stores them in a vector database (Chroma).
# - Uses a retriever to fetch the most relevant filing evidence for a given question.
# - Wraps retrieval as an agent tool (`search_tsla_docs`) and pairs it with a Python tool for **reproducible financial calculations** (e.g., revenue growth, margins, free cash flow, CAPEX).
# - Produces a structured earnings analysis report along with a JSON output, both with **explicit source and page-level citations**.
#
# **Why it matters**
# - Grounds LLM-generated analysis directly in primary financial filings, reducing hallucinations.
# - Ensures all numerical claims are auditable and computed programmatically.
# - Generates portfolio-ready outputs: a human-readable report and a machine-friendly JSON summary.

# %% [markdown]
# ![RAG - Indexing](https://mintcdn.com/langchain-5e9cc07a/I6RpA28iE233vhYX/images/rag_indexing.png?w=840&fit=max&auto=format&n=I6RpA28iE233vhYX&q=85&s=1838328a870c7353c42bf1cc2290a779)

# %% [markdown]
# 架構圖
#
# ```text
# User Question
#   ↓
# LLM (Agent Brain)
#   ↓ decides which tool(s) to use
# Tools
#   ├─ search_tsla_docs(query)  → retrieves evidence from TSLA filings
#   └─ python(query/code)       → computes financial metrics (audit-ready)
#   ↓
# Final Answer
#   ├─ Structured TSLA report
#   └─ JSON summary (machine-readable)
# ```
#
# > Key idea: Retrieval provides evidence, Python provides verifiable numbers, and the LLM provides reasoning + narrative.

# %% [markdown]
# # 套件與環境

# %%
# %%capture
# !pip install -qU langchain
# !pip install -qU langchain-openai
# !pip install -qU langchain_community
# !pip install -qU langchain_experimental
# !pip install -qU langchain-chroma>=0.1.2
# !pip install -qU chromadb
# !pip install -qU pypdf
# !pip install -qU python-dotenv

# %%
# %%capture
# !pip install -U \
  langchain>=0.2.0 \
  langchain-core>=0.2.0 \
  langchain-community>=0.2.0 \
  langchain-openai>=0.2.0 \
  langchain-text-splitters>=0.2.0 \
  chromadb \
  pydantic \
  pypdf \
  python-dotenv

# %% [markdown]
# # Environment & Config

# %%
import os

from dotenv import load_dotenv
import os

load_dotenv()  # 自動讀取 .env
assert os.getenv("OPENAI_API_KEY") is not None
# os.environ["OPENAI_API_KEY"]

# %% [markdown]
# # Download TSLA PDF

# %%
import requests
from pathlib import Path
# 載入 Tesla PDF（10-Q / Shareholder Letter / Earnings PDF）
url = "https://ir.tesla.com/_flysystem/s3/sec/000162828025045968/tsla-20250930-gen.pdf"

pdf_dir = Path("data/tsla")
pdf_dir.mkdir(parents=True, exist_ok=True)

pdf_path = pdf_dir / Path(url).name  # 自動用網址最後一段當檔名

# ✅ 下載（可重跑：檔案已存在就不重抓）
if not pdf_path.exists():
    resp = requests.get(url, timeout=60)
    resp.raise_for_status()
    pdf_path.write_bytes(resp.content)

# ✅ 基本 sanity check：檔案大小不要太小
size_mb = pdf_path.stat().st_size / (1024 * 1024)
print(f"PDF saved: {pdf_path} ({size_mb:.2f} MB)")
# Out:
# PDF saved: data/tsla/tsla-20250930-gen.pdf (0.31 MB)

# %% [markdown]
# # Load PDF into LangChain Documents

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter

text_splitter = RecursiveCharacterTextSplitter(
    chunk_size=1000,
    chunk_overlap=200,
    add_start_index=True, # 會在 metadata 裡加起始位置，對 debug 很好
)

splits = text_splitter.split_documents(docs)

print(f"Split into {len(splits)} chunks")
print("Example chunk meta:", splits[0].metadata)
print("Example chunk preview:", splits[0].page_content[:200])
# Out:
# Split into 183 chunks
# Example chunk meta: {'producer': 'Qt 5.15.2', 'creator': 'wkhtmltopdf 0.12.6', 'creationdate': '2025-10-23T10:11:25+00:00', 'title': '', 'source': 'https://ir.tesla.com/_flysystem/s3/sec/000162828025045968/tsla-20250930-gen.pdf', 'total_pages': 42, 'page': 0, 'page_label': '1', 'company': 'TSLA', 'source_file': 'tsla-20250930-gen.pdf', 'start_index': 0}
# Example chunk preview: UNITED	STATES
# SECURITIES	AND	EXCHANGE	COMMISSION
# Washington,	D.C.	20549
# FORM
# 10-Q
# (Mark	One)
# x
# QUARTERLY	REPORT	PURSUANT	TO	SECTION	13	OR	15(d)	OF	THE	SECURITIES	EXCHANGE	ACT	OF	1934
# For	the	quarterl

# %%
from langchain_community.document_loaders import PyPDFLoader

loader = PyPDFLoader(str(pdf_path))
docs = loader.load() # docs 是「一頁一個 Document」

# ✅ 補 metadata（RAG 關鍵）
for d in docs: # metadata 後面會被用在 citation
    d.metadata.update({
        "company": "TSLA",
        "source": url,
        "source_file": pdf_path.name
    })

print(f"Loaded {len(docs)} pages")
print("Example metadata:", docs[0].metadata)
# Out:
# Loaded 42 pages
# Example metadata: {'producer': 'Qt 5.15.2', 'creator': 'wkhtmltopdf 0.12.6', 'creationdate': '2025-10-23T10:11:25+00:00', 'title': '', 'source': 'https://ir.tesla.com/_flysystem/s3/sec/000162828025045968/tsla-20250930-gen.pdf', 'total_pages': 42, 'page': 0, 'page_label': '1', 'company': 'TSLA', 'source_file': 'tsla-20250930-gen.pdf'}

# %% [markdown]
# # Split Documents into Chunks

# %% [markdown]
# # Create / Load VectorStore (Chroma) + Embed

# %%
from langchain_openai import OpenAIEmbeddings
from langchain_community.vectorstores import Chroma

embedding = OpenAIEmbeddings(model="text-embedding-3-large")

persist_dir = "./tsla_chroma" # 是 資料庫所在的資料夾
collection_name = "tsla_earnings_pdf" # 是 資料庫裡的一個「表 / 命名空間」

docsearch = Chroma(
    collection_name=collection_name, # 如果 collection 已存在 → 讀取；不存在 → 建立新的
    persist_directory=persist_dir,
    embedding_function=embedding,
)

# ✅ 避免重複寫入：先試著查一下有沒有資料
# Chroma 沒有統一的 count API（不同版本差異很大），最簡單用小查詢測試
probe = docsearch.similarity_search("Tesla", k=1)

if len(probe) == 0:
    ids = docsearch.add_documents(splits)
    docsearch.persist()  # 有些版本需要顯式 persist
    print(f"Indexed {len(ids)} chunks into Chroma")
else:
    print("Chroma already has vectors, skip indexing.")
# Out:
# Indexed 183 chunks into Chroma
# /var/folders/rs/7clwcy050c7gyjz5lqt8kk_00000gn/T/ipykernel_3155/1711036058.py:21: LangChainDeprecationWarning: Since Chroma 0.4.x the manual persistence method is no longer supported as docs are automatically persisted.
#   docsearch.persist()  # 有些版本需要顯式 persist

# %% [markdown]
# ```python
# docsearch.add_documents(splits)
# ```
#
# 實際做了 4 件事：
#
# - 1️⃣ 對 splits[i].page_content 呼叫 OpenAI Embeddings
# - 2️⃣ 產生向量（1536 / 3072 維）
# - 3️⃣ 存進 Chroma collection
# - 4️⃣ 回傳每筆的 document_id (ids)

# %% [markdown]
# # Similarity Search Sanity Check

# %%
query = "revenue growth"
results = docsearch.similarity_search(query, k=3)

print(f"Query: {query}")
print(f"Top results: {len(results)}")

for i, r in enumerate(results, 1):
    meta = r.metadata
    print(f"\n--- Result {i} ---")
    print(f"(source={meta.get('source_file')}, page={meta.get('page')})")
    print(r.page_content[:400])
# Out:
# Query: revenue growth
# Top results: 3
#
# --- Result 1 ---
# (source=tsla-20250930-gen.pdf, page=31)
# volume	and	insurance	business	revenue.
# Energy	Generation	and	Storage	Segment
# Energy	generation	and	storage	revenue	increased	$1.04	billion,	or	44%,	in	the	three	months	ended	September	30,	2025	as	compared	to	the	three
# months	ended	September	30,	2024.	Energy	generation	and	storage	revenue	increased	$1.91	billion,	or	27%,	in	the	nine	months	ended	September	30,	2025	as
# compared	to	the	nine	months	end
#
# --- Result 2 ---
# (source=tsla-20250930-gen.pdf, page=32)
# the	nine	months	ended	September	30,	2024.	The	decreases	were	primarily	due	to	the	changes	in	automotive	sales	revenue	and	cost	of	automotive	sales
# revenue,	as	discussed	above,	as	well	as	decreases	in	regulatory	credits	revenue.
# 33
#
# --- Result 3 ---
# (source=tsla-20250930-gen.pdf, page=25)
# Revenues
# $
# 3,415
#
# $
# 2,376
#
# $
# 8,934
#
# $
# 7,025
#
# Cost	of	revenues	(2)
# $
# 2,342
#
# $
# 1,651
#
# $
# 6,230
#
# $
# 5,157
#
# Gross	profit
# $
# 1,073
#
# $
# 725
#
# $
# 2,704
#
# $
# 1,868
#
# (1)
# Depreciation	and	amortization	included	in	Cost	of	revenues	for	the	automotive	segment	for	the	three	and	nine	months	ended	September	30,	2025	was
# $
# 959
# 	million	and	$
# 2.80
# 	billion,	respectively.	Depreciation	and	amortization	included	i

# %% [markdown]
# # Create Retriever (for RAG/Agent)

# %%
retriever = docsearch.as_retriever(search_kwargs={"k": 5})

test_query = "Robotaxi and FSD timeline"
docs_hit = retriever.invoke(test_query)

print(f"Retriever hits: {len(docs_hit)}")
for i, d in enumerate(docs_hit, 1):
    print(f"\n--- Hit {i} ---")
    print(d.page_content[:300])
    print(d.metadata)
# Out:
# Retriever hits: 5
#
# --- Hit 1 ---
# including	through	product	offerings	and	features	utilizing	artificial	intelligence	such	as	Autopilot,	FSD	(Supervised),	and	other	software,	and	delivering	new
# vehicles	and	vehicle	options.	In	addition,	we	believe	the	launch	of	our	Robotaxi	service	unlocks	the	potential	for	significant	business	growt
# {'page': 28, 'creationdate': '2025-10-23T10:11:25+00:00', 'company': 'TSLA', 'source': 'https://ir.tesla.com/_flysystem/s3/sec/000162828025045968/tsla-20250930-gen.pdf', 'total_pages': 42, 'producer': 'Qt 5.15.2', 'creator': 'wkhtmltopdf 0.12.6', 'page_label': '29', 'start_index': 2989, 'source_file': 'tsla-20250930-gen.pdf', 'title': ''}
#
# --- Hit 2 ---
# the	Second	Circuit	affirmed	the	lower	court’s	order	and	dismissed	the	case.	On	March	22,	2023,	the	plaintiffs	in	the	Northern	District	of	California
# consolidated	action	filed	a	motion	for	a	preliminary	injunction	to	order	Tesla	to	(1)	cease	using	the	term	“Full	Self-Driving	Capability”	(FSD	Capabili
# {'source': 'https://ir.tesla.com/_flysystem/s3/sec/000162828025045968/tsla-20250930-gen.pdf', 'page_label': '24', 'total_pages': 42, 'creator': 'wkhtmltopdf 0.12.6', 'company': 'TSLA', 'page': 23, 'producer': 'Qt 5.15.2', 'source_file': 'tsla-20250930-gen.pdf', 'title': '', 'start_index': 1610, 'creationdate': '2025-10-23T10:11:25+00:00'}
#
# --- Hit 3 ---
# We	are	focused	on	profitable	growth	via	a	differentiated	and	efficiently	managed	product	portfolio	that	leverages	our	existing	factories	and	production	lines,
# further	improving	and	deploying	our	FSD	(Supervised)	capabilities,	including	future	autonomous	capabilities	through	our	purpose-built	Robotax
# {'creator': 'wkhtmltopdf 0.12.6', 'company': 'TSLA', 'creationdate': '2025-10-23T10:11:25+00:00', 'source_file': 'tsla-20250930-gen.pdf', 'total_pages': 42, 'producer': 'Qt 5.15.2', 'page': 27, 'page_label': '28', 'title': '', 'start_index': 1538, 'source': 'https://ir.tesla.com/_flysystem/s3/sec/000162828025045968/tsla-20250930-gen.pdf'}
#
# --- Hit 4 ---
# September	30,	2024,	due	to	a	decrease	of	approximately	24,000	deliveries	of	other	models	and	a	decrease	of	approximately	49,000	combined	Model	3	and
# Model	Y	cash	deliveries	in	part	from	bringing	down	all	of	our	vehicle	factories	simultaneously	for	the	changeover	to	New	Model	Y.	Additionally,	there	w
# {'producer': 'Qt 5.15.2', 'source_file': 'tsla-20250930-gen.pdf', 'source': 'https://ir.tesla.com/_flysystem/s3/sec/000162828025045968/tsla-20250930-gen.pdf', 'page': 31, 'total_pages': 42, 'company': 'TSLA', 'creationdate': '2025-10-23T10:11:25+00:00', 'creator': 'wkhtmltopdf 0.12.6', 'start_index': 714, 'page_label': '32', 'title': ''}
#
# --- Hit 5 ---
# November	6,	2023,	Tesla	moved	to	dismiss	the	amended	complaint.	On	September	30,	2024,	the	Court	granted	Tesla’s	motion	to	dismiss	without	prejudice.
# On	November	26,	2024,	the	court	issued	a	final	judgment	in	Tesla’s	favor,	and	on	December	23,	2024,	the	plaintiffs	filed	a	notice	of	appeal	to	the	Uni
# {'title': '', 'page_label': '24', 'source': 'https://ir.tesla.com/_flysystem/s3/sec/000162828025045968/tsla-20250930-gen.pdf', 'creator': 'wkhtmltopdf 0.12.6', 'producer': 'Qt 5.15.2', 'company': 'TSLA', 'start_index': 3945, 'source_file': 'tsla-20250930-gen.pdf', 'creationdate': '2025-10-23T10:11:25+00:00', 'page': 23, 'total_pages': 42}

# %% [markdown]
# # Initialize OpenAI LLM

# %%
from langchain_openai import ChatOpenAI

llm = ChatOpenAI(
    model="gpt-5.2",  # 或 gpt-4.1
    temperature=0
)

# %% [markdown]
# # Tools（search + python）

# %% [markdown]
# ### 🧠 這段程式在 Agent 架構中的角色
#
# | 層級 | 你現在這段的角色 |
# |------|------------------|
# | VectorStore | 已完成 |
# | Retriever | 已完成 |
# | Tool | ✅ 就是這段 |
# | Agent Brain | 之後用 `create_agent` |
# | Reasoning | 由 LLM 負責 |

# %%
from typing import List
from langchain_core.tools import tool
from langchain_core.documents import Document
from langchain_experimental.tools import PythonREPLTool

python_tool = PythonREPLTool()

@tool("search_tsla_docs") # 告訴 LangChain：「這是一個 LLM 可以用的工具」。
def search_tsla_docs(query: str) -> str: 
    """
    Search TSLA earnings call transcripts, shareholder letters, and filings.
    Input: a natural language query
    Output: concatenated text with source/page metadata for evidence
    """
    # 把檢索結果拿出來，放到docs變數，是個 List[Document] 型態
    docs: List[Document] = retriever.invoke(query)  # retriever = docsearch.as_retriever() or ParentDocumentRetriever
    if not docs:
        return "No relevant documents found."

    # 把結果整理成「可引用」的格式（source/page 是 RAG 的命）
    chunks = []
    for i, d in enumerate(docs, 1): # enumerate 是取list的 index 跟 value
        meta = d.metadata or {} # 防止 metadata 是 None
        src = meta.get("source_file") or meta.get("source") or meta.get("source_id") or "unknown_source" # 取得來源資訊
        page = meta.get("page", "NA") # 取得頁碼，沒有就 NA
        text = (d.page_content or "").strip().replace("\n", " ") # 移除換行
        chunks.append(f"[{i}] source={src} page={page}\n{text}") # 把每個 chunk 加進去，chunks是 list of strings

    return "\n\n".join(chunks) # 把所有 chunk 用雙換行接起來，變成一個大字串 (因為 Agent Tool 的黃金法則是：Tool output = LLM 會直接讀的文字)

# Tools 組合：把「可用工具（查文件 + 算數字）」交給 LLM，讓它變成一個會查證、會計算的財報研究員（Agent）。
tools = [search_tsla_docs, python_tool]

# %% [markdown]
# 你現在回傳的格式，LLM 會這樣理解：
# ```text
# [1] source=tsla-20250930-gen.pdf page=12
# Tesla reported automotive gross margin...
#
# [2] source=...
# ```

# %% [markdown]
# # Agent（create_agent）

# %%
from langchain.agents import create_agent

system_prompt = """
You are a financial research agent specialized in Tesla (TSLA).

Rules (MUST follow):
1) ALWAYS call the tool `search_tsla_docs` before making any factual/qualitative claim.
2) ALL numerical metrics (growth, margins, FCF, CAPEX) MUST be computed using the python tool.
3) Cite evidence as: (source=..., page=...)
4) If information is missing, explicitly say what is missing.
5) Output must follow the exact TSLA_TEMPLATE structure.
6) Do NOT invent numbers.

Tool usage:
- Use search_tsla_docs for evidence retrieval.
- Use python for calculations, tables, and any numeric derivations.

When you cite, cite the exact page you used.
"""

agent = create_agent(
    model=llm,            # OpenAI Chat model instance
    tools=tools,
    system_prompt=system_prompt
)

# %% [markdown]
# # TSLA_TEMPLATE（一次）

# %%
TSLA_TEMPLATE = """
Produce a TSLA earnings analysis using the following structure:

Company: Tesla, Inc. (TSLA)
Period: Latest reported quarter (based on the provided documents)

Sections:
1. One-Line Verdict (Bull / Bear / Mixed)
2. Key Highlights (with citations)
3. Key Risks (with citations)
4. Financial Performance Snapshot (table)
   - Revenue, YoY, QoQ
   - Gross Margin, Operating Margin
   - Free Cash Flow (FCF), CAPEX
5. AI, Autonomy & Product Roadmap (with citations)
6. Forward-Looking Catalysts (with citations if mentioned)
7. Market Focus: what investors should watch next quarter
8. Open Questions (explicitly list missing info)
9. Citations (a clean list)

Also output a JSON object at the end, wrapped in a ```json code block``` with:
- verdict
- highlights
- risks
- financials (revenue growth, margins, FCF, CAPEX)
- ai_autonomy
- citations
"""

# %% [markdown]
# # Demo Query（一次）

# %%
from langchain_core.messages import HumanMessage

query = f"""
Analyze TSLA's latest earnings based ONLY on the indexed TSLA PDF(s).

{TSLA_TEMPLATE}

Questions to answer:
- What are the main positives and negatives this quarter?
- How are margins and free cash flow trending?
- What did management say about FSD, Robotaxi, and AI investment?
- What metrics will investors focus on next quarter?

Important:
- Use `search_tsla_docs` to retrieve evidence before claims.
- Use python tool for calculations (no mental math).
- Always cite (source=..., page=...) for qualitative statements.
"""

result = agent.invoke({"messages": [HumanMessage(content=query)]})

# %% [markdown]
# # 乾淨輸出（Final report + JSON block）

# %%
# ✅ 最終答案通常是最後一則 message
final_text = result["messages"][-1].content

print(final_text)
# Out:
# Company: Tesla, Inc. (TSLA)
# Period: **Q3 2025 (three months ended September 30, 2025)** (source=tsla-20250930-gen.pdf, page=30)
#
# ---
#
# ## 1. One-Line Verdict (Bull / Bear / Mixed)
# **Mixed** — Revenue grew YoY, but **gross/operating margins declined materially** and key cash-flow items needed for quarterly FCF are **not disclosed** in the provided PDF. (source=tsla-20250930-gen.pdf, page=30) (source=tsla-20250930-gen.pdf, page=32)
#
# ---
#
# ## 2. Key Highlights (with citations)
# - **Total revenue increased to $28.10B (+12% YoY)** in Q3 2025. (source=tsla-20250930-gen.pdf, page=30)
# - **Energy generation & storage revenue grew 44% YoY** (to $3.42B), attributed to higher Megapack/Powerwall deployments (with some offset from lower Megapack ASP). (source=tsla-20250930-gen.pdf, page=30) (source=tsla-20250930-gen.pdf, page=31)
# - **Services & other revenue grew 25% YoY** (to $3.48B), driven by used vehicle sales volume, paid Supercharging sessions, maintenance/collision revenue, and insurance revenue. (source=tsla-20250930-gen.pdf, page=31)
# - Tesla states it has **continued to expand/refine its Robotaxi service after its June 2025 launch**, leveraging AI investments and mobility infrastructure. (source=tsla-20250930-gen.pdf, page=27)
# - Tesla ended Q3 2025 with **$41.65B in cash/cash equivalents and investments**. (source=tsla-20250930-gen.pdf, page=27)
#
# ---
#
# ## 3. Key Risks (with citations)
# - **Margin pressure drivers**: Tesla notes automotive cost/revenue dynamics including **lower fixed-cost absorption, tariffs, and sales mix**; and that automotive gross margin declined YoY. (source=tsla-20250930-gen.pdf, page=32)
# - **Regulatory credits volatility**: regulatory credits revenue declined **44% YoY** in Q3 2025 and depends on regulation and third-party demand. (source=tsla-20250930-gen.pdf, page=31)
# - **Macro/trade policy uncertainty**: Tesla highlights evolving trade/fiscal policy uncertainty, risks to supply chain/cost structure, and that the current tariff regime may impact energy more than automotive. (source=tsla-20250930-gen.pdf, page=28)
# - **Cyclicality/affordability**: higher interest rates can impact vehicle affordability and therefore operating margin. (source=tsla-20250930-gen.pdf, page=29)
#
# ---
#
# ## 4. Financial Performance Snapshot (table)
#
# **Note on QoQ / quarterly FCF & quarterly CAPEX:** The provided indexed PDF includes Q3 2025 and Q3 2024 income statement lines, but **does not provide Q2 2025 revenue**, and provides **cash flow / CAPEX only on a nine-month basis** (not quarterly). Therefore, QoQ revenue and quarterly FCF/CAPEX are **missing** from the provided documents. (source=tsla-20250930-gen.pdf, page=30) (source=tsla-20250930-gen.pdf, page=36)
#
# | Metric | Q3 2025 | Q3 2024 | YoY | QoQ |
# |---|---:|---:|---:|---:|
# | Revenue ($B) | 28.095 | 25.182 | 11.6% | **Missing** |
# | Gross Margin (%) | 18.0% | 19.8% | -1.9 pp | **Missing** |
# | Operating Margin (%) | 5.8% | 10.8% | -5.0 pp | **Missing** |
# | Free Cash Flow (FCF) ($B) | **Missing (quarter)** | **Missing (quarter)** | **Missing** | **Missing** |
# | CAPEX ($B) | **Missing (quarter)** | **Missing (quarter)** | **Missing** | **Missing** |
#
# **Evidence used:** Revenue and margins derived from stated revenue / gross profit / operating income in the 10-Q tables. (source=tsla-20250930-gen.pdf, page=30) (source=tsla-20250930-gen.pdf, page=4) (source=tsla-20250930-gen.pdf, page=32)
#
# **Additional cash flow context (9M, not quarterly):**
# - Net cash from operations (9M 2025): **$10.934B** vs **$10.109B** (9M 2024). (source=tsla-20250930-gen.pdf, page=36)
# - CAPEX (9M 2025): **$6.13B** vs **$8.56B** (9M 2024). (source=tsla-20250930-gen.pdf, page=36)
# - Implied FCF (9M) = CFO − CAPEX: **$4.804B** (9M 2025) vs **$1.549B** (9M 2024). (source=tsla-20250930-gen.pdf, page=36)
#
# ---
#
# ## 5. AI, Autonomy & Product Roadmap (with citations)
# - Tesla emphasizes improving and deploying **FSD (Supervised)** and pursuing **future autonomous capabilities** via its purpose-built Robotaxi product (**Cybercab**). (source=tsla-20250930-gen.pdf, page=27)
# - Tesla states it believes the **launch of its Robotaxi service** can unlock significant growth and enable a service-driven business model; it plans to improve safety/profitability while scaling. (source=tsla-20250930-gen.pdf, page=28)
# - Production roadmap table lists **Cybercab (Construction)**, **Tesla Semi (Construction)**, and **Roadster (In development)**. (source=tsla-20250930-gen.pdf, page=28)
# - Tesla notes it is capitalizing on real-world AI data to advance **Optimus**, described as a “general purpose, autonomous humanoid robot.” (source=tsla-20250930-gen.pdf, page=28)
# - Tesla links CAPEX variability primarily to capital expenditures “mainly for **AI-related capital expenditures**” and factory expansion (nine-month basis). (source=tsla-20250930-gen.pdf, page=36)
#
# **What management said about FSD, Robotaxi, and AI investment (based only on provided PDF):**
# - FSD: focus on “further improving and deploying” FSD (Supervised). (source=tsla-20250930-gen.pdf, page=27)
# - Robotaxi: service launched June 2025; continued expansion/refinement and belief it can drive significant growth. (source=tsla-20250930-gen.pdf, page=27) (source=tsla-20250930-gen.pdf, page=28)
# - AI investment: ongoing investments mentioned broadly; CAPEX described as including “AI-related capital expenditures” (9M). (source=tsla-20250930-gen.pdf, page=36)
#
# ---
#
# ## 6. Forward-Looking Catalysts (with citations if mentioned)
# - Tesla expects **2025 CAPEX ~ $9.0B**, noting trade policy changes may require timeline adjustments. (source=tsla-20250930-gen.pdf, page=35)
# - Tesla frames the “next phase of production growth” as driven by **advances in autonomy** and **introduction of new products**, including those on a next-generation vehicle platform. (source=tsla-20250930-gen.pdf, page=28)
# - Scaling Robotaxi: Tesla discusses continued scaling with focus on safety and profitability. (source=tsla-20250930-gen.pdf, page=28)
#
# ---
#
# ## 7. Market Focus: what investors should watch next quarter
# - **Automotive gross margin trajectory** (Tesla explicitly reports YoY decline in automotive gross margin). (source=tsla-20250930-gen.pdf, page=32)
# - **Regulatory credits trend** (Q3 YoY decline and inherent volatility). (source=tsla-20250930-gen.pdf, page=31)
# - **Energy growth and profitability durability** (energy revenue up strongly; energy gross margin shown at 31.4% in Q3 2025). (source=tsla-20250930-gen.pdf, page=30) (source=tsla-20250930-gen.pdf, page=32)
# - **Robotaxi scaling indicators** (service launched June 2025; ongoing expansion/refinement). (source=tsla-20250930-gen.pdf, page=27)
# - **CAPEX execution vs. ~$9B 2025 plan** and the extent to which spend remains “AI-related.” (source=tsla-20250930-gen.pdf, page=35) (source=tsla-20250930-gen.pdf, page=36)
#
# ---
#
# ## 8. Open Questions (explicitly list missing info)
# Missing from the provided indexed TSLA PDF(s) (needed to fully answer the requested items):
# - **QoQ revenue** for “latest reported quarter” (Q2 2025 revenue not shown in the excerpts/tables retrieved). (Missing in provided excerpts; only Q3 2025 vs Q3 2024 shown) (source=tsla-20250930-gen.pdf, page=30)
# - **Quarterly FCF and quarterly CAPEX** for Q3 2025: cash flow and CAPEX are presented on a **nine-month** basis; quarterly CAPEX/CFO not provided in the retrieved tables. (source=tsla-20250930-gen.pdf, page=36)
# - Any specific **FSD take-rate, miles driven, disengagements, Robotaxi fleet size/coverage, or Robotaxi economics** — not provided in the retrieved pages. (Missing)
# - Any explicit **quarterly guidance** for next quarter revenue/margins — not provided in retrieved pages (only general outlook language). (source=tsla-20250930-gen.pdf, page=28)
#
# ---
#
# ## 9. Citations (a clean list)
# - (source=tsla-20250930-gen.pdf, page=4)
# - (source=tsla-20250930-gen.pdf, page=27)
# - (source=tsla-20250930-gen.pdf, page=28)
# - (source=tsla-20250930-gen.pdf, page=29)
# - (source=tsla-20250930-gen.pdf, page=30)
# - (source=tsla-20250930-gen.pdf, page=31)
# - (source=tsla-20250930-gen.pdf, page=32)
# - (source=tsla-20250930-gen.pdf, page=35)
# - (source=tsla-20250930-gen.pdf, page=36)
#
# ```json
# {
#   "verdict": "Mixed",
#   "highlights": [
#     {
#       "item": "Q3 2025 total revenue increased to $28.10B (+12% YoY).",
#       "citations": [
#         "source=tsla-20250930-gen.pdf, page=30"
#       ]
#     },
#     {
#       "item": "Energy generation & storage revenue rose 44% YoY to $3.42B, driven by higher Megapack/Powerwall deployments (partially offset by lower Megapack ASP).",
#       "citations": [
#         "source=tsla-20250930-gen.pdf, page=30",
#         "source=tsla-20250930-gen.pdf, page=31"
#       ]
#     },
#     {
#       "item": "Services & other revenue grew 25% YoY to $3.48B (used vehicles, Supercharging, maintenance/collision, insurance).",
#       "citations": [
#         "source=tsla-20250930-gen.pdf, page=31"
#       ]
#     },
#     {
#       "item": "Robotaxi service launched June 2025; Tesla states it has continued to expand/refine the service.",
#       "citations": [
#         "source=tsla-20250930-gen.pdf, page=27"
#       ]
#     }
#   ],
#   "risks": [
#     {
#       "item": "Automotive gross margin declined YoY; Tesla cites factors including lower fixed-cost absorption, tariffs, and sales mix.",
#       "citations": [
#         "source=tsla-20250930-gen.pdf, page=32"
#       ]
#     },
#     {
#       "item": "Regulatory credits revenue declined 44% YoY and is inherently volatile based on regulation and third-party demand.",
#       "citations": [
#         "source=tsla-20250930-gen.pdf, page=31"
#       ]
#     },
#     {
#       "item": "Trade/fiscal policy uncertainty poses risks to supply chain/cost structure; tariff regime expected to impact energy more than automotive.",
#       "citations": [
#         "source=tsla-20250930-gen.pdf, page=28"
#       ]
#     },
#     {
#       "item": "Vehicle demand and operating margin sensitivity to macro conditions (interest rates/affordability).",
#       "citations": [
#         "source=tsla-20250930-gen.pdf, page=29"
#       ]
#     }
#   ],
#   "financials": {
#     "revenue": {
#       "q3_2025_usd_m": 28095,
#       "q3_2024_usd_m": 25182,
#       "yoy_growth_pct": 11.567786514176803,
#       "qoq_growth_pct": null,
#       "citations": [
#         "source=tsla-20250930-gen.pdf, page=30"
#       ]
#     },
#     "margins": {
#       "gross_margin_pct_q3_2025": 17.98896600818651,
#       "gross_margin_pct_q3_2024": 19.843539035819235,
#       "operating_margin_pct_q3_2025": 5.780387969389571,
#       "operating_margin_pct_q3_2024": 10.789452783734414,
#       "citations": [
#         "source=tsla-20250930-gen.pdf, page=4",
#         "source=tsla-20250930-gen.pdf, page=30",
#         "source=tsla-20250930-gen.pdf, page=32"
#       ]
#     },
#     "fcf": {
#       "quarterly_fcf_usd_m": null,
#       "nine_month_fcf_usd_m": 4804,
#       "nine_month_fcf_usd_m_prior": 1549,
#       "citations": [
#         "source=tsla-20250930-gen.pdf, page=36"
#       ]
#     },
#     "capex": {
#       "quarterly_capex_usd_m": null,
#       "nine_month_capex_usd_m": 6130,
#       "nine_month_capex_usd_m_prior": 8560,
#       "citations": [
#         "source=tsla-20250930-gen.pdf, page=36"
#       ]
#     }
#   },
#   "ai_autonomy": [
#     {
#       "item": "Focus on improving/deploying FSD (Supervised) and future autonomous capabilities via Robotaxi product Cybercab.",
#       "citations": [
#         "source=tsla-20250930-gen.pdf, page=27"
#       ]
#     },
#     {
#       "item": "Tesla believes Robotaxi service can unlock significant growth; plans to scale with safety and profitability improvements.",
#       "citations": [
#         "source=tsla-20250930-gen.pdf, page=28"
#       ]
#     },
#     {
#       "item": "CAPEX mainly for AI-related expenditures and factory expansion (9M context).",
#       "citations": [
#         "source=tsla-20250930-gen.pdf, page=36"
#       ]
#     },
#     {
#       "item": "Optimus described as a general purpose autonomous humanoid robot; development leverages real-world AI data.",
#       "citations": [
#         "source=tsla-20250930-gen.pdf, page=28"
#       ]
#     }
#   ],
#   "citations": [
#     "source=tsla-20250930-gen.pdf, page=4",
#     "source=tsla-20250930-gen.pdf, page=27",
#     "source=tsla-20250930-gen.pdf, page=28",
#     "source=tsla-20250930-gen.pdf, page=29",
#     "source=tsla-20250930-gen.pdf, page=30",
#     "source=tsla-20250930-gen.pdf, page=31",
#     "source=tsla-20250930-gen.pdf, page=32",
#     "source=tsla-20250930-gen.pdf, page=35",
#     "source=tsla-20250930-gen.pdf, page=36"
#   ]
# }
# ```

# %% [markdown]
# ## （可選）加一個「自動切出 JSON 區塊」方便展示

# %%
import re

final_text = result["messages"][-1].content

# 嘗試抓 ```json ... ``` 區塊
m = re.search(r"```json\s*(\{.*?\})\s*```", final_text, flags=re.DOTALL)
json_block = m.group(1) if m else None

print("===== FINAL REPORT =====")
print(final_text)

print("\n===== EXTRACTED JSON =====")
if json_block:
    print(json_block)
else:
    print("No JSON block found. (The model may not have produced a json code block.)")
# Out:
# ===== FINAL REPORT =====
# Company: Tesla, Inc. (TSLA)
# Period: **Q3 2025 (three months ended September 30, 2025)** (source=tsla-20250930-gen.pdf, page=30)
#
# ---
#
# ## 1. One-Line Verdict (Bull / Bear / Mixed)
# **Mixed** — Revenue grew YoY, but **gross/operating margins declined materially** and key cash-flow items needed for quarterly FCF are **not disclosed** in the provided PDF. (source=tsla-20250930-gen.pdf, page=30) (source=tsla-20250930-gen.pdf, page=32)
#
# ---
#
# ## 2. Key Highlights (with citations)
# - **Total revenue increased to $28.10B (+12% YoY)** in Q3 2025. (source=tsla-20250930-gen.pdf, page=30)
# - **Energy generation & storage revenue grew 44% YoY** (to $3.42B), attributed to higher Megapack/Powerwall deployments (with some offset from lower Megapack ASP). (source=tsla-20250930-gen.pdf, page=30) (source=tsla-20250930-gen.pdf, page=31)
# - **Services & other revenue grew 25% YoY** (to $3.48B), driven by used vehicle sales volume, paid Supercharging sessions, maintenance/collision revenue, and insurance revenue. (source=tsla-20250930-gen.pdf, page=31)
# - Tesla states it has **continued to expand/refine its Robotaxi service after its June 2025 launch**, leveraging AI investments and mobility infrastructure. (source=tsla-20250930-gen.pdf, page=27)
# - Tesla ended Q3 2025 with **$41.65B in cash/cash equivalents and investments**. (source=tsla-20250930-gen.pdf, page=27)
#
# ---
#
# ## 3. Key Risks (with citations)
# - **Margin pressure drivers**: Tesla notes automotive cost/revenue dynamics including **lower fixed-cost absorption, tariffs, and sales mix**; and that automotive gross margin declined YoY. (source=tsla-20250930-gen.pdf, page=32)
# - **Regulatory credits volatility**: regulatory credits revenue declined **44% YoY** in Q3 2025 and depends on regulation and third-party demand. (source=tsla-20250930-gen.pdf, page=31)
# - **Macro/trade policy uncertainty**: Tesla highlights evolving trade/fiscal policy uncertainty, risks to supply chain/cost structure, and that the current tariff regime may impact energy more than automotive. (source=tsla-20250930-gen.pdf, page=28)
# - **Cyclicality/affordability**: higher interest rates can impact vehicle affordability and therefore operating margin. (source=tsla-20250930-gen.pdf, page=29)
#
# ---
#
# ## 4. Financial Performance Snapshot (table)
#
# **Note on QoQ / quarterly FCF & quarterly CAPEX:** The provided indexed PDF includes Q3 2025 and Q3 2024 income statement lines, but **does not provide Q2 2025 revenue**, and provides **cash flow / CAPEX only on a nine-month basis** (not quarterly). Therefore, QoQ revenue and quarterly FCF/CAPEX are **missing** from the provided documents. (source=tsla-20250930-gen.pdf, page=30) (source=tsla-20250930-gen.pdf, page=36)
#
# | Metric | Q3 2025 | Q3 2024 | YoY | QoQ |
# |---|---:|---:|---:|---:|
# | Revenue ($B) | 28.095 | 25.182 | 11.6% | **Missing** |
# | Gross Margin (%) | 18.0% | 19.8% | -1.9 pp | **Missing** |
# | Operating Margin (%) | 5.8% | 10.8% | -5.0 pp | **Missing** |
# | Free Cash Flow (FCF) ($B) | **Missing (quarter)** | **Missing (quarter)** | **Missing** | **Missing** |
# | CAPEX ($B) | **Missing (quarter)** | **Missing (quarter)** | **Missing** | **Missing** |
#
# **Evidence used:** Revenue and margins derived from stated revenue / gross profit / operating income in the 10-Q tables. (source=tsla-20250930-gen.pdf, page=30) (source=tsla-20250930-gen.pdf, page=4) (source=tsla-20250930-gen.pdf, page=32)
#
# **Additional cash flow context (9M, not quarterly):**
# - Net cash from operations (9M 2025): **$10.934B** vs **$10.109B** (9M 2024). (source=tsla-20250930-gen.pdf, page=36)
# - CAPEX (9M 2025): **$6.13B** vs **$8.56B** (9M 2024). (source=tsla-20250930-gen.pdf, page=36)
# - Implied FCF (9M) = CFO − CAPEX: **$4.804B** (9M 2025) vs **$1.549B** (9M 2024). (source=tsla-20250930-gen.pdf, page=36)
#
# ---
#
# ## 5. AI, Autonomy & Product Roadmap (with citations)
# - Tesla emphasizes improving and deploying **FSD (Supervised)** and pursuing **future autonomous capabilities** via its purpose-built Robotaxi product (**Cybercab**). (source=tsla-20250930-gen.pdf, page=27)
# - Tesla states it believes the **launch of its Robotaxi service** can unlock significant growth and enable a service-driven business model; it plans to improve safety/profitability while scaling. (source=tsla-20250930-gen.pdf, page=28)
# - Production roadmap table lists **Cybercab (Construction)**, **Tesla Semi (Construction)**, and **Roadster (In development)**. (source=tsla-20250930-gen.pdf, page=28)
# - Tesla notes it is capitalizing on real-world AI data to advance **Optimus**, described as a “general purpose, autonomous humanoid robot.” (source=tsla-20250930-gen.pdf, page=28)
# - Tesla links CAPEX variability primarily to capital expenditures “mainly for **AI-related capital expenditures**” and factory expansion (nine-month basis). (source=tsla-20250930-gen.pdf, page=36)
#
# **What management said about FSD, Robotaxi, and AI investment (based only on provided PDF):**
# - FSD: focus on “further improving and deploying” FSD (Supervised). (source=tsla-20250930-gen.pdf, page=27)
# - Robotaxi: service launched June 2025; continued expansion/refinement and belief it can drive significant growth. (source=tsla-20250930-gen.pdf, page=27) (source=tsla-20250930-gen.pdf, page=28)
# - AI investment: ongoing investments mentioned broadly; CAPEX described as including “AI-related capital expenditures” (9M). (source=tsla-20250930-gen.pdf, page=36)
#
# ---
#
# ## 6. Forward-Looking Catalysts (with citations if mentioned)
# - Tesla expects **2025 CAPEX ~ $9.0B**, noting trade policy changes may require timeline adjustments. (source=tsla-20250930-gen.pdf, page=35)
# - Tesla frames the “next phase of production growth” as driven by **advances in autonomy** and **introduction of new products**, including those on a next-generation vehicle platform. (source=tsla-20250930-gen.pdf, page=28)
# - Scaling Robotaxi: Tesla discusses continued scaling with focus on safety and profitability. (source=tsla-20250930-gen.pdf, page=28)
#
# ---
#
# ## 7. Market Focus: what investors should watch next quarter
# - **Automotive gross margin trajectory** (Tesla explicitly reports YoY decline in automotive gross margin). (source=tsla-20250930-gen.pdf, page=32)
# - **Regulatory credits trend** (Q3 YoY decline and inherent volatility). (source=tsla-20250930-gen.pdf, page=31)
# - **Energy growth and profitability durability** (energy revenue up strongly; energy gross margin shown at 31.4% in Q3 2025). (source=tsla-20250930-gen.pdf, page=30) (source=tsla-20250930-gen.pdf, page=32)
# - **Robotaxi scaling indicators** (service launched June 2025; ongoing expansion/refinement). (source=tsla-20250930-gen.pdf, page=27)
# - **CAPEX execution vs. ~$9B 2025 plan** and the extent to which spend remains “AI-related.” (source=tsla-20250930-gen.pdf, page=35) (source=tsla-20250930-gen.pdf, page=36)
#
# ---
#
# ## 8. Open Questions (explicitly list missing info)
# Missing from the provided indexed TSLA PDF(s) (needed to fully answer the requested items):
# - **QoQ revenue** for “latest reported quarter” (Q2 2025 revenue not shown in the excerpts/tables retrieved). (Missing in provided excerpts; only Q3 2025 vs Q3 2024 shown) (source=tsla-20250930-gen.pdf, page=30)
# - **Quarterly FCF and quarterly CAPEX** for Q3 2025: cash flow and CAPEX are presented on a **nine-month** basis; quarterly CAPEX/CFO not provided in the retrieved tables. (source=tsla-20250930-gen.pdf, page=36)
# - Any specific **FSD take-rate, miles driven, disengagements, Robotaxi fleet size/coverage, or Robotaxi economics** — not provided in the retrieved pages. (Missing)
# - Any explicit **quarterly guidance** for next quarter revenue/margins — not provided in retrieved pages (only general outlook language). (source=tsla-20250930-gen.pdf, page=28)
#
# ---
#
# ## 9. Citations (a clean list)
# - (source=tsla-20250930-gen.pdf, page=4)
# - (source=tsla-20250930-gen.pdf, page=27)
# - (source=tsla-20250930-gen.pdf, page=28)
# - (source=tsla-20250930-gen.pdf, page=29)
# - (source=tsla-20250930-gen.pdf, page=30)
# - (source=tsla-20250930-gen.pdf, page=31)
# - (source=tsla-20250930-gen.pdf, page=32)
# - (source=tsla-20250930-gen.pdf, page=35)
# - (source=tsla-20250930-gen.pdf, page=36)
#
# ```json
# {
#   "verdict": "Mixed",
#   "highlights": [
#     {
#       "item": "Q3 2025 total revenue increased to $28.10B (+12% YoY).",
#       "citations": [
#         "source=tsla-20250930-gen.pdf, page=30"
#       ]
#     },
#     {
#       "item": "Energy generation & storage revenue rose 44% YoY to $3.42B, driven by higher Megapack/Powerwall deployments (partially offset by lower Megapack ASP).",
#       "citations": [
#         "source=tsla-20250930-gen.pdf, page=30",
#         "source=tsla-20250930-gen.pdf, page=31"
#       ]
#     },
#     {
#       "item": "Services & other revenue grew 25% YoY to $3.48B (used vehicles, Supercharging, maintenance/collision, insurance).",
#       "citations": [
#         "source=tsla-20250930-gen.pdf, page=31"
#       ]
#     },
#     {
#       "item": "Robotaxi service launched June 2025; Tesla states it has continued to expand/refine the service.",
#       "citations": [
#         "source=tsla-20250930-gen.pdf, page=27"
#       ]
#     }
#   ],
#   "risks": [
#     {
#       "item": "Automotive gross margin declined YoY; Tesla cites factors including lower fixed-cost absorption, tariffs, and sales mix.",
#       "citations": [
#         "source=tsla-20250930-gen.pdf, page=32"
#       ]
#     },
#     {
#       "item": "Regulatory credits revenue declined 44% YoY and is inherently volatile based on regulation and third-party demand.",
#       "citations": [
#         "source=tsla-20250930-gen.pdf, page=31"
#       ]
#     },
#     {
#       "item": "Trade/fiscal policy uncertainty poses risks to supply chain/cost structure; tariff regime expected to impact energy more than automotive.",
#       "citations": [
#         "source=tsla-20250930-gen.pdf, page=28"
#       ]
#     },
#     {
#       "item": "Vehicle demand and operating margin sensitivity to macro conditions (interest rates/affordability).",
#       "citations": [
#         "source=tsla-20250930-gen.pdf, page=29"
#       ]
#     }
#   ],
#   "financials": {
#     "revenue": {
#       "q3_2025_usd_m": 28095,
#       "q3_2024_usd_m": 25182,
#       "yoy_growth_pct": 11.567786514176803,
#       "qoq_growth_pct": null,
#       "citations": [
#         "source=tsla-20250930-gen.pdf, page=30"
#       ]
#     },
#     "margins": {
#       "gross_margin_pct_q3_2025": 17.98896600818651,
#       "gross_margin_pct_q3_2024": 19.843539035819235,
#       "operating_margin_pct_q3_2025": 5.780387969389571,
#       "operating_margin_pct_q3_2024": 10.789452783734414,
#       "citations": [
#         "source=tsla-20250930-gen.pdf, page=4",
#         "source=tsla-20250930-gen.pdf, page=30",
#         "source=tsla-20250930-gen.pdf, page=32"
#       ]
#     },
#     "fcf": {
#       "quarterly_fcf_usd_m": null,
#       "nine_month_fcf_usd_m": 4804,
#       "nine_month_fcf_usd_m_prior": 1549,
#       "citations": [
#         "source=tsla-20250930-gen.pdf, page=36"
#       ]
#     },
#     "capex": {
#       "quarterly_capex_usd_m": null,
#       "nine_month_capex_usd_m": 6130,
#       "nine_month_capex_usd_m_prior": 8560,
#       "citations": [
#         "source=tsla-20250930-gen.pdf, page=36"
#       ]
#     }
#   },
#   "ai_autonomy": [
#     {
#       "item": "Focus on improving/deploying FSD (Supervised) and future autonomous capabilities via Robotaxi product Cybercab.",
#       "citations": [
#         "source=tsla-20250930-gen.pdf, page=27"
#       ]
#     },
#     {
#       "item": "Tesla believes Robotaxi service can unlock significant growth; plans to scale with safety and profitability improvements.",
#       "citations": [
#         "source=tsla-20250930-gen.pdf, page=28"
#       ]
#     },
#     {
#       "item": "CAPEX mainly for AI-related expenditures and factory expansion (9M context).",
#       "citations": [
#         "source=tsla-20250930-gen.pdf, page=36"
#       ]
#     },
#     {
#       "item": "Optimus described as a general purpose autonomous humanoid robot; development leverages real-world AI data.",
#       "citations": [
#         "source=tsla-20250930-gen.pdf, page=28"
#       ]
#     }
#   ],
#   "citations": [
#     "source=tsla-20250930-gen.pdf, page=4",
#     "source=tsla-20250930-gen.pdf, page=27",
#     "source=tsla-20250930-gen.pdf, page=28",
#     "source=tsla-20250930-gen.pdf, page=29",
#     "source=tsla-20250930-gen.pdf, page=30",
#     "source=tsla-20250930-gen.pdf, page=31",
#     "source=tsla-20250930-gen.pdf, page=32",
#     "source=tsla-20250930-gen.pdf, page=35",
#     "source=tsla-20250930-gen.pdf, page=36"
#   ]
# }
# ```
#
# ===== EXTRACTED JSON =====
# {
#   "verdict": "Mixed",
#   "highlights": [
#     {
#       "item": "Q3 2025 total revenue increased to $28.10B (+12% YoY).",
#       "citations": [
#         "source=tsla-20250930-gen.pdf, page=30"
#       ]
#     },
#     {
#       "item": "Energy generation & storage revenue rose 44% YoY to $3.42B, driven by higher Megapack/Powerwall deployments (partially offset by lower Megapack ASP).",
#       "citations": [
#         "source=tsla-20250930-gen.pdf, page=30",
#         "source=tsla-20250930-gen.pdf, page=31"
#       ]
#     },
#     {
#       "item": "Services & other revenue grew 25% YoY to $3.48B (used vehicles, Supercharging, maintenance/collision, insurance).",
#       "citations": [
#         "source=tsla-20250930-gen.pdf, page=31"
#       ]
#     },
#     {
#       "item": "Robotaxi service launched June 2025; Tesla states it has continued to expand/refine the service.",
#       "citations": [
#         "source=tsla-20250930-gen.pdf, page=27"
#       ]
#     }
#   ],
#   "risks": [
#     {
#       "item": "Automotive gross margin declined YoY; Tesla cites factors including lower fixed-cost absorption, tariffs, and sales mix.",
#       "citations": [
#         "source=tsla-20250930-gen.pdf, page=32"
#       ]
#     },
#     {
#       "item": "Regulatory credits revenue declined 44% YoY and is inherently volatile based on regulation and third-party demand.",
#       "citations": [
#         "source=tsla-20250930-gen.pdf, page=31"
#       ]
#     },
#     {
#       "item": "Trade/fiscal policy uncertainty poses risks to supply chain/cost structure; tariff regime expected to impact energy more than automotive.",
#       "citations": [
#         "source=tsla-20250930-gen.pdf, page=28"
#       ]
#     },
#     {
#       "item": "Vehicle demand and operating margin sensitivity to macro conditions (interest rates/affordability).",
#       "citations": [
#         "source=tsla-20250930-gen.pdf, page=29"
#       ]
#     }
#   ],
#   "financials": {
#     "revenue": {
#       "q3_2025_usd_m": 28095,
#       "q3_2024_usd_m": 25182,
#       "yoy_growth_pct": 11.567786514176803,
#       "qoq_growth_pct": null,
#       "citations": [
#         "source=tsla-20250930-gen.pdf, page=30"
#       ]
#     },
#     "margins": {
#       "gross_margin_pct_q3_2025": 17.98896600818651,
#       "gross_margin_pct_q3_2024": 19.843539035819235,
#       "operating_margin_pct_q3_2025": 5.780387969389571,
#       "operating_margin_pct_q3_2024": 10.789452783734414,
#       "citations": [
#         "source=tsla-20250930-gen.pdf, page=4",
#         "source=tsla-20250930-gen.pdf, page=30",
#         "source=tsla-20250930-gen.pdf, page=32"
#       ]
#     },
#     "fcf": {
#       "quarterly_fcf_usd_m": null,
#       "nine_month_fcf_usd_m": 4804,
#       "nine_month_fcf_usd_m_prior": 1549,
#       "citations": [
#         "source=tsla-20250930-gen.pdf, page=36"
#       ]
#     },
#     "capex": {
#       "quarterly_capex_usd_m": null,
#       "nine_month_capex_usd_m": 6130,
#       "nine_month_capex_usd_m_prior": 8560,
#       "citations": [
#         "source=tsla-20250930-gen.pdf, page=36"
#       ]
#     }
#   },
#   "ai_autonomy": [
#     {
#       "item": "Focus on improving/deploying FSD (Supervised) and future autonomous capabilities via Robotaxi product Cybercab.",
#       "citations": [
#         "source=tsla-20250930-gen.pdf, page=27"
#       ]
#     },
#     {
#       "item": "Tesla believes Robotaxi service can unlock significant growth; plans to scale with safety and profitability improvements.",
#       "citations": [
#         "source=tsla-20250930-gen.pdf, page=28"
#       ]
#     },
#     {
#       "item": "CAPEX mainly for AI-related expenditures and factory expansion (9M context).",
#       "citations": [
#         "source=tsla-20250930-gen.pdf, page=36"
#       ]
#     },
#     {
#       "item": "Optimus described as a general purpose autonomous humanoid robot; development leverages real-world AI data.",
#       "citations": [
#         "source=tsla-20250930-gen.pdf, page=28"
#       ]
#     }
#   ],
#   "citations": [
#     "source=tsla-20250930-gen.pdf, page=4",
#     "source=tsla-20250930-gen.pdf, page=27",
#     "source=tsla-20250930-gen.pdf, page=28",
#     "source=tsla-20250930-gen.pdf, page=29",
#     "source=tsla-20250930-gen.pdf, page=30",
#     "source=tsla-20250930-gen.pdf, page=31",
#     "source=tsla-20250930-gen.pdf, page=32",
#     "source=tsla-20250930-gen.pdf, page=35",
#     "source=tsla-20250930-gen.pdf, page=36"
#   ]
# }
